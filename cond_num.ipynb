# %%
import numpy
import seaborn as sns
from scipy.io import loadmat

# %%
contents = loadmat('condNumAnalysis_noMask.mat')

# %%
delta = contents['delta'].ravel()

# %%
results = contents['results']

# %%
sns.lineplot(delta, results[1, :])
sns.lineplot(delta, results[2, :])
sns.lineplot(delta, results[3, :])
sns.lineplot(delta, results[4, :])
sns.lineplot(delta, results[5, :])
sns.lineplot(delta, results[6, :])
